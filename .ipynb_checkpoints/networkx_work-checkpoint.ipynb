# %%
# %pylab inline
import networkx as nx
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
g = nx.Graph()

g.add_edges_from([np.random.randint(0,20, (2)) for _ in range(20)])

nx.draw(g)

# %%
connected = [g.subgraph(c) for c in nx.connected_components(g) if len(c)>4][0]
nx.draw(connected)

# %%
u,v = nx.maximum_(connected).pop()
new_g = nx.Graph(connected)
new_g.remove_edge(u,v)
nx.draw(new_g)

# %%
import pandas as pd

# %%
'''df = pd.read_csv('/Users/mgbvox/Downloads/2008_BSA_Inpatient_Claims_PUF.csv', encoding='latin1')

df[['IP_CLM_BASE_DRG_CD','IP_DRG_QUINT_PMT_AVG', 'IP_DRG_QUINT_PMT_CD']]

proc_quintile_df = df.groupby(['IP_CLM_BASE_DRG_CD','IP_DRG_QUINT_PMT_CD'])[['IP_DRG_QUINT_PMT_AVG']].mean().T

proc_quintile_df[199][2]

# !pip install xlutils
# !pip install xlrd

dfs = {}
for year in range(2014,2018):
    path = f'/Users/mgbvox/Downloads/Medicare_Fee-For-Service_Enrollment_by_State_CY{year}.xlsx'
    df = pd.read_excel(path)
    dfs[year] = df


big = pd.read_csv('/Users/mgbvox/Downloads/Medicare_Provider_Util_Payment_PUF_CY2017/Medicare_Provider_Util_Payment_PUF_CY2017.txt', sep='\t')

big.shape

data = big.dropna()

data.to_csv('provider_data.csv')'''
pass

# %%
'''
START HERE
'''
import pandas as pd
from pandarallel import pandarallel

pandarallel.initialize(progress_bar=True)
# Out:
# '\nSTART HERE\n'

# %%
data = pd.read_csv('provider_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cf0555ed1163> in <module>
# ----> 1 data = pd.read_csv('provider_data.csv')
#
# NameError: name 'pd' is not defined

# %%
code_avgs = data.groupby('hcpcs_code')['average_submitted_chrg_amt'].mean()

# %%
sub = data.iloc[:10000]

# %%
sub['charge_delta'] = sub.apply(lambda x: x.average_submitted_chrg_amt - code_avgs[x.hcpcs_code], axis=1)
# Out:
# /Users/mgbvox/opt/anaconda3/envs/ds/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sub.groupby(['nppes_provider_last_org_name'])['charge_delta'].mean().sort_values()
# Out:
# nppes_provider_last_org_name
# FLEMING     -3672.527871
# POIRIER     -3363.275719
# REED        -2863.699464
# LUCERO      -2198.376819
# KUHLMAN     -1931.696560
#                 ...
# ZDON         2102.808867
# RADVINSKY    3519.407778
# STUMPF       3890.872119
# YURCISIN     4178.751978
# KHAROD       4373.134680
# Name: charge_delta, Length: 960, dtype: float64

# %%
'''
Look at how doctors are clustering/not clustering around different procedures;
Weight edges by avg procedure pricing for that doctor
For nodes of high clustering:
    1) Find edge weight outliers
    2) See if doctors with those outliers are charging similarly high prices in other clusters.
'''
# Out:
#      Unnamed: 0         npi nppes_provider_last_org_name  \
# 0            12  1003000134                       CIBULL
# 1            13  1003000134                       CIBULL
# 2            14  1003000134                       CIBULL
# 3            15  1003000134                       CIBULL
# 4            16  1003000134                       CIBULL
# ..          ...         ...                          ...
# 995        3238  1003017682                       AKHTAR
# 996        3239  1003017682                       AKHTAR
# 997        3240  1003017682                       AKHTAR
# 998        3241  1003017682                       AKHTAR
# 999        3242  1003017682                       AKHTAR
#
#     nppes_provider_first_name nppes_provider_mi nppes_credentials  \
# 0                      THOMAS                 L              M.D.
# 1                      THOMAS                 L              M.D.
# 2                      THOMAS                 L              M.D.
# 3                      THOMAS                 L              M.D.
# 4                      THOMAS                 L              M.D.
# ..                        ...               ...               ...
# 995                    NAUMAN                 J              M.D.
# 996                    NAUMAN                 J              M.D.
# 997                    NAUMAN                 J              M.D.
# 998                    NAUMAN                 J              M.D.
# 999                    NAUMAN                 J              M.D.
#
#     nppes_provider_gender nppes_entity_code nppes_provider_street1  \
# 0                       M                 I         2650 RIDGE AVE
# 1                       M                 I         2650 RIDGE AVE
# 2                       M                 I         2650 RIDGE AVE
# 3                       M                 I         2650 RIDGE AVE
# 4                       M                 I         2650 RIDGE AVE
# ..                    ...               ...                    ...
# 995                     M                 I    224D CORNWALL ST NW
# 996                     M                 I    224D CORNWALL ST NW
# 997                     M                 I    224D CORNWALL ST NW
# 998                     M                 I    224D CORNWALL ST NW
# 999                     M                 I    224D CORNWALL ST NW
#
#     nppes_provider_street2  ...  \
# 0        EVANSTON HOSPITAL  ...
# 1        EVANSTON HOSPITAL  ...
# 2        EVANSTON HOSPITAL  ...
# 3        EVANSTON HOSPITAL  ...
# 4        EVANSTON HOSPITAL  ...
# ..                     ...  ...
# 995              SUITE 204  ...
# 996              SUITE 204  ...
# 997              SUITE 204  ...
# 998              SUITE 204  ...
# 999              SUITE 204  ...
#
#                                      hcpcs_description hcpcs_drug_indicator  \
# 0    Pathology examination of tissue using a micros...                    N
# 1    Pathology examination of tissue using a micros...                    N
# 2    Special stained specimen slides to identify or...                    N
# 3    Special stained specimen slides to examine tis...                    N
# 4           Surgical pathology consultation and report                    N
# ..                                                 ...                  ...
# 995  Computer-assisted surgical navigational proced...                    N
# 996  Replacement of thigh bone and hip joint prosth...                    N
# 997  Open treatment of broken thigh bone with inser...                    N
# 998            Surgical treatment of broken thigh bone                    N
# 999                               Repair of knee joint                    N
#
#     line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 0           268.0           249.0             252.0
# 1          6162.0          3481.0            4489.0
# 2           438.0           289.0             294.0
# 3            86.0            63.0              65.0
# 4            27.0            27.0              27.0
# ..            ...             ...               ...
# 995          41.0            40.0              41.0
# 996          22.0            21.0              22.0
# 997          17.0            17.0              17.0
# 998          13.0            13.0              13.0
# 999          48.0            45.0              48.0
#
#     average_Medicare_allowed_amt average_submitted_chrg_amt  \
# 0                      12.789739                 115.000000
# 1                      41.299942                 170.000000
# 2                      29.240251                  88.000000
# 3                      13.137558                  68.000000
# 4                      92.750000                 273.555556
# ..                           ...                        ...
# 995                   149.800000                 343.000000
# 996                  1376.500000                4067.000000
# 997                  1177.808824                3126.000000
# 998                  1248.950000                3824.000000
# 999                  1375.830000                4270.000000
#
#     average_Medicare_payment_amt average_Medicare_standard_amt charge_delta
# 0                       9.842127                      9.390821    13.275450
# 1                      31.426415                     30.401900     2.429932
# 2                      22.700525                     22.163379   -29.683436
# 3                      10.298140                      9.849535   -10.664176
# 4                      67.333333                     64.083333   -14.866870
# ..                           ...                           ...          ...
# 995                   117.440000                    119.860000  -367.158056
# 996                  1072.658182                   1093.908636 -1042.807561
# 997                   923.398235                    941.616471  -551.421702
# 998                   979.180000                    997.078462  -674.525719
# 999                  1077.147500                   1098.357917  -492.918823
#
# [1000 rows x 28 columns]
